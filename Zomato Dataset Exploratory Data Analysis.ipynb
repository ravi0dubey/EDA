# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# it will display all matplotlib graph inside jupyter notebook
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
#We get UTF-Encoding error so we will use encoding = Latin-1
df_zomato= pd.read_csv("D:\Study\Data Science\Dataset\Zomatodataset\zomato.csv",encoding= 'latin-1')
df_zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# higher version of pandas does not support excel so we need to install openpyxl
pip install openpyxl

# %%
# higher version of pandas does not support excel so we need to open with engine = 'openpyxl'

df_country= pd.read_excel("D:\Study\Data Science\Dataset\Zomatodataset\Country-Code.xlsx", engine='openpyxl', sheet_name = 'Sheet1')
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
#Step 1 Basic columns verification of Zomato Dataset
df_zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Zomato Dataset Verification of columns and its datatypes along with Not-Null Values
df_zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#It will only show analysis of Numerical Values
df_zomato.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#It will only show analysis of Numerical Values
df_zomato.describe(include = "all")
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                            Address         Locality  \
# count                         9551             9551
# unique                        8918             1208
# ...

# %% [markdown]
# # Steps to be performed in Data Analysis
#
# 1. Missing Values
# 2. Explore About the Numerical Variables
# 3. Explore About Categorical Values
# 4. Finding Realtionship between Features

# %% [markdown]
# # 1. Missing Values

# %%
#It will let me know if any Features has missing values
df_zomato.isnull().sum()

#Feature Cuisines has 9 missing values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#another way of finding specific columns which has null values

list_null_features= []

for features in df_zomato.columns:
    if df_zomato[features].isnull().sum()>0:
        list_null_features.append(features)   
        
print(list_null_features)
# Out:
# ['Cuisines']

# %%
#Using heatmap to plot missing values
sns.set(rc = {'figure.figsize':(10,20)})
sns.heatmap(df_zomato.isnull(),yticklabels=False,cbar= False,cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
#Since we have Country code common in both the dataset, we will Merge the dataset based on Country code

df_final= pd.merge(df_zomato,df_country,on="Country Code", how = 'left')
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Verification of columns and its datatypes
df_final.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# Final Dataset Verification of columns and its datatypes along with Not-Null Values
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # Duplicate Value Analysis

# %%
#To check if any records are duplicate
df_final.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %%
#To print list of all city which has duplicate values
df_final[df_final['City'].duplicated()]
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# 5          18189371              Din Tai Fung           162  Mandaluyong City
# 7           6301290                   Vikings           162        Pasay City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# Analysis of Country Column to see different values and their counts
df_final.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
#Plotting Top 3 Countries and the count in Pie Chart

country_names = df_final.Country.value_counts().index
country_count = df_final.Country.value_counts().values
plt.pie(country_count[:3], labels =  country_names[:3],autopct = '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d8471a2580>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# # Observations from Zomato Dataset based on number of Transactions
#
# 1. Zomato Maximum Transaction are from India which is 94+%
# 2. Second is United States with 4.73%
# 3. Followed by United Kingdome which is 0.87%

# %%
#To identify numerical variables
df_final[df_final.dtypes[df_final.dtypes !='object'].index]
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#       Average Cost for two  Price range  Aggregate rating  Votes
# 0                     1100            3               4.8    314
# 1                     1200            3               4.5    591
# 2                     4000            4               4.4    270
# ...

# %%
#To get columns which has Numerical Values in it
df_final.dtypes[df_final.dtypes !='object'].index
# Out:
# Index(['Restaurant ID', 'Country Code', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df_final.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
# To Arrange above data into Dataframe we need to convert it using reset_index
# Count does not have any Header label, Header Label will get displayed as 0
# so we will use rename function to set its name to Rating_Count
df_final.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating_Count'} )
# Out:
#     Aggregate rating Rating color Rating text  Rating_Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
#save the Group By output in a dataset which will be used for plotting the graphs
ratings= df_final.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating_Count'} )
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating_Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# # Observation Based on Ratings
#
# 1. 2.1k people has not given Ratings
# 2. Any Rating given below 2.4 and above 0 it is Poor Ratings
# 3. Rating between 2.5 to 3.4 is Average Ratings
# 4. Rating between 3.5 to 3.9, People have given Good Ratings
# 5. Rating between 4.0 to 4.4, People have given Very Good Rating
# 6. Rating between 4.5 to 4.9, People have given Excellent Ratings

# %%
#Plotting Graph based on Rating Count and Aggregate Rating
sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x="Aggregate rating", y="Rating_Count", data=ratings,)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating_Count'>

# %%
#Plotting Graph based on Rating Count and Aggregate Rating and color of barplot is based on Rating Color
sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x="Aggregate rating", y="Rating_Count", data=ratings,hue="Rating color", palette=['White','Red','Orange','Yellow','Green','Green',])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating_Count'>

# %% [markdown]
# # Observations
# 1. Not Rated Count is Very High
# 2. Maximum number of Rating are between 2.5 and 3.4

# %%
#How many times color appears in dataset Ratings we can plot it below
sns.countplot(x="Rating color", data=ratings,hue="Rating color", palette=['White','Red','Orange','Yellow','Green','Green',])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
# Question : Find the list of countries and Count of Individual ratings
df_final.groupby(['Country','Aggregate rating']).size().reset_index().rename(columns={0:'Rating_Count'} )
# Out:
#            Country  Aggregate rating  Rating_Count
# 0        Australia               2.4             1
# 1        Australia               2.6             1
# 2        Australia               2.9             1
# 3        Australia               3.2             1
# 4        Australia               3.4             1
# ..             ...               ...           ...
# 217  United States               4.5            24
# 218  United States               4.6            18
# 219  United States               4.7             9
# 220  United States               4.8             3
# 221  United States               4.9            14
#
# [222 rows x 3 columns]

# %%
# #Question : Find the list of countries which has given 0 ratings
df_country_zero_ratings = df_final[df_final['Aggregate rating']==0][['Country']]
df_country_zero_ratings
# Out:
#              Country
# 30            Brazil
# 58            Brazil
# 69            Brazil
# 77            Brazil
# 78            Brazil
# ...              ...
# 9109           India
# 9110           India
# 9111           India
# 9112           India
# 9351  United Kingdom
#
# [2148 rows x 1 columns]

# %%
pd.DataFrame(df_country_zero_ratings.groupby('Country')['Country'].count())
# Out:
#                 Country
# Country
# Brazil                5
# India              2139
# United Kingdom        1
# United States         3

# %%
#Find the list of countries and Count which has given 0 ratings
df_final[df_final['Aggregate rating']==0].groupby('Country').size().reset_index().rename(columns={0:'Rating_Count'} )
# Out:
#           Country  Rating_Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# # Observations
#
# 1. Maximum Number of '0' Ratings are from INDIA

# %%
#Question : List down Countries and the Currency
df_final[['Country','Currency',]].groupby(['Country','Currency']).size().reset_index().rename(columns={0:'Currency_Count'})
# Out:
#            Country                Currency  Currency_Count
# 0        Australia               Dollar($)              24
# 1           Brazil      Brazilian Real(R$)              60
# 2           Canada               Dollar($)               4
# 3            India      Indian Rupees(Rs.)            8652
# 4        Indonesia  Indonesian Rupiah(IDR)              21
# 5      New Zealand           NewZealand($)              40
# 6      Phillipines        Botswana Pula(P)              22
# 7            Qatar         Qatari Rial(QR)              20
# 8        Singapore               Dollar($)              20
# 9     South Africa                 Rand(R)              60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)              20
# 11          Turkey        Turkish Lira(TL)              34
# 12             UAE      Emirati Diram(AED)              60
# 13  United Kingdom              Pounds(£)              80
# 14   United States               Dollar($)             434

# %%
#Question Which Countries do have Online Deliveries
df_final[df_final['Has Online delivery']=='Yes'].groupby(['Country']).size().reset_index().rename(columns={0:'OnlineDelivery_Count'})
# Out:
#   Country  OnlineDelivery_Count
# 0   India                  2423
# 1     UAE                    28

# %%
df_final[['Country','City']]
# Out:
#           Country              City
# 0     Phillipines       Makati City
# 1     Phillipines       Makati City
# 2     Phillipines  Mandaluyong City
# 3     Phillipines  Mandaluyong City
# 4     Phillipines  Mandaluyong City
# ...           ...               ...
# 9546       Turkey         ÛÁstanbul
# 9547       Turkey         ÛÁstanbul
# 9548       Turkey         ÛÁstanbul
# 9549       Turkey         ÛÁstanbul
# 9550       Turkey         ÛÁstanbul
#
# [9551 rows x 2 columns]

# %%
#City Sorted based on Maximum Transaction

df_city_max= df_final.groupby(['Country','City']).size().reset_index().rename(columns={0:'City_Count'}).sort_values(by = ['City_Count'], ascending=False)
df_city_max
# Out:
#            Country            City  City_Count
# 61           India       New Delhi        5473
# 45           India         Gurgaon        1118
# 62           India           Noida        1080
# 42           India       Faridabad         251
# 43           India       Ghaziabad          25
# ..             ...             ...         ...
# 63           India       Panchkula           1
# 1        Australia        Balingup           1
# 73       Indonesia         Bandung           1
# 83     Phillipines     Quezon City           1
# 140  United States  Winchester Bay           1
#
# [141 rows x 3 columns]

# %%
#Plotting Top 5 Cities and the count in Pie Chart

city_names = df_city_max['City'].head(5)
city_count = df_city_max['City_Count'].head(5)
plt.pie(city_count, labels =  city_names,autopct = '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d853c36940>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [markdown]
# # Observations
# 1. Maximum Transaction Happened in India
# 2. Delhi has 68% of Transaction
# 3. Gurgaon follows with 14%

# %%
# Cuisines Sorted based on Maximum Transaction

df_cuisines_max= df_final.groupby(['Country','Cuisines']).size().reset_index().rename(columns={0:'Cuisines_Count'}).sort_values(by = ['Cuisines_Count'], ascending=False)
df_cuisines_max
# Out:
#             Country                                    Cuisines  \
# 1012          India                                North Indian
# 1035          India                       North Indian, Chinese
# 648           India                                   Fast Food
# 364           India                                     Chinese
# 1218          India                       North Indian, Mughlai
# ...             ...                                         ...
# 770           India                          Hyderabadi, Awadhi
# 768           India   Healthy Food, Salad, Italian, Continental
# 766           India  Healthy Food, North Indian, Italian, Salad
# 765           India     Healthy Food, North Indian, Continental
# 1987  United States                                  Vietnamese
#
#       Cuisines_Count
# 1012             936
# 1035             511
# 648              348
# 364              340
# 1218             334
# ...              ...
# 770                1
# ...

# %%
#Plotting Top 5 Cuisines and the count in Pie Chart

cuisines_names = df_cuisines_max['Cuisines'].head(5)
cuisines_count = df_cuisines_max['Cuisines_Count'].head(5)
plt.pie(cuisines_count, labels =  cuisines_names,autopct = '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d850e20760>,
# ...
#  [Text(0.40782439721501956, 1.021606216228252, 'North Indian'),
#   Text(-1.0934206458501399, 0.12013030936721664, 'North Indian, Chinese'),
#   Text(-0.6094532310743379, -0.9157329081850504, 'Fast Food'),
#   Text(0.31265184958340336, -1.0546320784766967, 'Chinese'),
#   Text(1.002148727787288, -0.45353933389985074, 'North Indian, Mughlai')],
#  [Text(0.22244967120819245, 0.5572397543063192, '37.91%'),
#   Text(-0.5964112613728035, 0.06552562329120908, '20.70%'),
#   Text(-0.332429035131457, -0.4994906771918456, '14.09%'),
#   Text(0.1705373725000382, -0.575253860987289, '13.77%'),
#   Text(0.5466265787930661, -0.24738509121810037, '13.53%')])

# %% [markdown]
# # Observations Related to Cuisines
# 1. North India Cuisines were most ordered. Its 37.91%
# 2. North India Chinese were 2nd Most ordered. Its 20.70%
# 3. Fast Food  followed  at 3rd spot with 14.09%
# 4. Chinese at 4th spot with 13.77%
# 5. North Indian Mughlai at 5th spot with 13.53%
